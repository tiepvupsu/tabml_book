# %%
# %%capture
import pandas as pd
from pandas_profiling import ProfileReport

df_train = pd.read_csv("../data/titanic/train.csv")

profile = ProfileReport(
    df_train, title="Pandas Profiling Report for Titanic train dataset"
)
profile.to_file("../data/data_to_web/titanic_profiling.html")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-94eb133e52b8> in <module>
#       7     df_train, title="Pandas Profiling Report for Titanic train dataset"
#       8 )
# ----> 9 profile.to_file("../data/data_to_web/titanic_profiling.html")
#
# ~/w/tabml-book/tabml_env/lib/python3.8/site-packages/pandas_profiling/profile_report.py in to_file(self, output_file, silent)
#     290             total=1, desc="Export report to file", disable=disable_progress_bar
#     291         ) as pbar:
# --> 292             output_file.write_text(data, encoding="utf-8")
#     293             pbar.update()
#     294
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/pathlib.py in write_text(self, data, encoding, errors)
#    1252             raise TypeError('data must be str, not %s' %
#    1253                             data.__class__.__name__)
# ...
